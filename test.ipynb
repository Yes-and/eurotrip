# %%
import pandas as pd

# %%
df = pd.read_csv("eurotrip-flights.csv")

# %%
df.head()
# Out:
#          date from.code  from.city to.code     to.city  price.czk
# 0  2022-07-01       AMS  Amsterdam     ARN   Stockholm       2447
# 1  2022-07-01       AMS  Amsterdam     ATH      Athens       4520
# 2  2022-07-01       AMS  Amsterdam     BEG    Belgrade       3040
# 3  2022-07-01       AMS  Amsterdam     BRN        Bern       1380
# 4  2022-07-01       AMS  Amsterdam     BTS  Bratislava       2208

# %%
{i:[] for i in sorted(df["date"].unique())}
# Out:
# {'2022-07-01': [],
#  '2022-07-02': [],
#  '2022-07-03': [],
#  '2022-07-04': [],
#  '2022-07-05': [],
#  '2022-07-06': [],
#  '2022-07-07': [],
#  '2022-07-08': [],
#  '2022-07-09': [],
#  '2022-07-10': [],
#  '2022-07-11': [],
#  '2022-07-12': [],
#  '2022-07-13': [],
#  '2022-07-14': [],
#  '2022-07-15': [],
#  '2022-07-16': [],
#  '2022-07-17': [],
#  '2022-07-18': [],
#  '2022-07-19': [],
#  '2022-07-20': [],
#  '2022-07-21': [],
#  '2022-07-22': [],
#  '2022-07-23': [],
#  '2022-07-24': [],
#  '2022-07-25': [],
#  '2022-07-26': [],
#  '2022-07-27': [],
#  '2022-07-28': [],
#  '2022-07-29': [],
#  '2022-07-30': [],
#  '2022-07-31': [],
#  '2022-08-01': [],
#  '2022-08-02': [],
#  '2022-08-03': [],
#  '2022-08-04': [],
#  '2022-08-05': [],
#  '2022-08-06': [],
#  '2022-08-07': [],
#  '2022-08-08': [],
#  '2022-08-09': [],
#  '2022-08-10': [],
#  '2022-08-11': [],
#  '2022-08-12': [],
#  '2022-08-13': [],
#  '2022-08-14': []}

# %%
df.shape[0]
# Out:
# 80854

# %%
dict(df.groupby(["date", "from.code"])["to.code"].count())
# Out:
# {('2022-07-01', 'AMS'): 38,
#  ('2022-07-01', 'ARN'): 41,
#  ('2022-07-01', 'ATH'): 40,
#  ('2022-07-01', 'BEG'): 40,
#  ('2022-07-01', 'BRN'): 41,
#  ('2022-07-01', 'BRU'): 42,
#  ('2022-07-01', 'BTS'): 39,
#  ('2022-07-01', 'BUD'): 37,
#  ('2022-07-01', 'CDG'): 41,
#  ('2022-07-01', 'CPH'): 41,
#  ('2022-07-01', 'DME'): 39,
#  ('2022-07-01', 'DUB'): 39,
#  ('2022-07-01', 'ESB'): 39,
#  ('2022-07-01', 'EVN'): 42,
#  ('2022-07-01', 'FCO'): 41,
#  ('2022-07-01', 'GYD'): 40,
#  ('2022-07-01', 'HEL'): 40,
#  ('2022-07-01', 'IEV'): 40,
#  ('2022-07-01', 'KIV'): 43,
#  ('2022-07-01', 'LHR'): 37,
#  ('2022-07-01', 'LIS'): 42,
#  ('2022-07-01', 'LJU'): 42,
#  ('2022-07-01', 'LUX'): 41,
#  ('2022-07-01', 'MAD'): 43,
#  ('2022-07-01', 'MLA'): 43,
#  ('2022-07-01', 'MSQ'): 37,
#  ('2022-07-01', 'NIC'): 44,
#  ('2022-07-01', 'OSL'): 40,
#  ('2022-07-01', 'OTP'): 41,
#  ('2022-07-01', 'PRG'): 42,
#  ('2022-07-01', 'PRN'): 33,
#  ('2022-07-01', 'RIX'): 41,
#  ('2022-07-01', 'RKV'): 44,
# ...

# %%
df.loc[df["from.code"]=="PRG"]
# Out:
#              date from.code from.city to.code    to.city  price.czk
# 1173   2022-07-01       PRG    Prague     AMS  Amsterdam       1694
# 1174   2022-07-01       PRG    Prague     ATH     Athens       2521
# 1175   2022-07-01       PRG    Prague     BEG   Belgrade       1620
# 1176   2022-07-01       PRG    Prague     BRN       Bern       1431
# 1177   2022-07-01       PRG    Prague     BRU   Brussels       1616
# ...           ...       ...       ...     ...        ...        ...
# 80269  2022-08-14       PRG    Prague     TXL     Berlin        754
# 80270  2022-08-14       PRG    Prague     VIE     Vienna        501
# 80271  2022-08-14       PRG    Prague     VNO    Vilnius       1961
# 80272  2022-08-14       PRG    Prague     WAW     Warsaw       1294
# 80273  2022-08-14       PRG    Prague     ZAG     Zagreb       1192
#
# [1845 rows x 6 columns]
